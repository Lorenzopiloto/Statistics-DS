# %% [markdown]
# <a href="https://colab.research.google.com/github/Lorenzopiloto/Statistics-DS/blob/main/Tratamento_de_Missings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tratamento de *missings*

# %% [markdown]
# ## Carregar libraries

# %%
import numpy as np
import pandas as pd
import io
from google.colab import files

# %%
np.__version__, pd.__version__
# Out:
# ('1.26.4', '2.2.2')

# %% [markdown]
# ## Carregar dados

# %%
#uploaded = files.upload()

# %%
#dados_hatco = pd.read_csv(io.StringIO(uploaded['hatco_csv.csv'].decode('utf-8')), sep=';', decimal=',')

# %%
dados_hatco = pd.read_csv('hatco_csv.csv', sep=';', decimal=',')

# %%
dados_hatco.tail(5)
# Out:
#       id  velocidade_entrega  nivel_preco  flexibilidade_preco  \
# 165  266                 4.2          2.4                  9.4
# 166  267                 3.8          0.8                  NaN
# 167  268                 3.3          2.6                  9.7
# 168  269                 NaN          1.9                  NaN
# 169  270                 4.5          1.6                  8.7
#
#      imagem_fornecedor  qualidade_servico  imagem_forca_vendas  \
# 165                4.9                3.2                  2.7
# 166                NaN                2.2                  2.6
# 167                3.3                2.9                  1.5
# 168                4.5                1.5                  3.1
# 169                4.6                3.1                  2.1
#
#      qualidade_produto tamanho_firma  nivel_uso  nivel_satisfacao  \
# 165                8.5       pequena       49.0               5.2
# 166                5.3       pequena       42.0               5.1
# 167                5.2       pequena       47.0               NaN
# 168                9.9        grande       39.0               3.3
# 169                6.8       pequena       56.0               5.1
#
#     area_industria
# 165      industria
# 166     outra_area
# 167      industria
# 168      industria
# 169     outra_area

# %%
dados_hatco.shape
# Out:
# (170, 12)

# %%
# detectar missing em uma coluna especifica
dados_hatco[dados_hatco['nivel_satisfacao'].isnull()]
# Out:
#       id  velocidade_entrega  nivel_preco  flexibilidade_preco  \
# 103  204                 NaN          1.5                  NaN
# 106  207                 NaN          1.5                  NaN
# 109  210                 4.1          3.7                  5.9
# 132  233                 4.5          NaN                  NaN
# 134  235                 3.8          0.8                  8.7
# 160  261                 3.6          NaN                  NaN
# 167  268                 3.3          2.6                  9.7
#
#      imagem_fornecedor  qualidade_servico  imagem_forca_vendas  \
# 103                4.8                1.9                  2.5
# 106                4.8                1.9                  2.5
# 109                NaN                NaN                  NaN
# 132                5.9                NaN                  NaN
# 134                2.9                1.6                  NaN
# 160                6.2                4.5                  NaN
# 167                3.3                2.9                  1.5
#
#      qualidade_produto tamanho_firma  nivel_uso  nivel_satisfacao  \
# 103                7.2        grande       36.0               NaN
# 106                7.2        grande       36.0               NaN
# 109                NaN           NaN        NaN               NaN
# 132                8.8        grande       50.0               NaN
# 134                5.6       pequena       39.0               NaN
# 160                NaN        grande        NaN               NaN
# 167                5.2       pequena       47.0               NaN
#
#     area_industria
# 103     outra_area
# 106     outra_area
# 109     outra_area
# 132     outra_area
# 134     outra_area
# 160      industria
# 167      industria

# %%
# retirar missing em uma coluna especifica
dados_hatco[~dados_hatco['nivel_satisfacao'].isnull()]
# Out:
#       id  velocidade_entrega  nivel_preco  flexibilidade_preco  \
# 0      1                 4.1          0.6                  6.9
# 1      2                 1.8          3.0                  6.3
# 2      3                 3.4          5.2                  5.7
# 3      4                 2.7          1.0                  7.1
# 4      5                 6.0          0.9                  9.6
# ..   ...                 ...          ...                  ...
# 164  265                 3.0          2.0                  6.6
# 165  266                 4.2          2.4                  9.4
# 166  267                 3.8          0.8                  NaN
# 168  269                 NaN          1.9                  NaN
# 169  270                 4.5          1.6                  8.7
#
#      imagem_fornecedor  qualidade_servico  imagem_forca_vendas  \
# 0                  4.7                2.4                  2.3
# 1                  6.6                2.5                  4.0
# 2                  6.0                4.3                  2.7
# 3                  5.9                1.8                  2.3
# 4                  7.8                3.4                  4.6
# ..                 ...                ...                  ...
# 164                6.6                2.4                  2.7
# 165                4.9                3.2                  2.7
# 166                NaN                2.2                  2.6
# 168                4.5                1.5                  3.1
# 169                4.6                3.1                  2.1
#
#      qualidade_produto tamanho_firma  nivel_uso  nivel_satisfacao  \
# 0                  5.2       pequena       32.0               4.2
# 1                  8.4        grande       43.0               4.3
# 2                  8.2        grande       48.0               5.2
# 3                  7.8        grande       32.0               3.9
# 4                  4.5       pequena       58.0               6.8
# ..                 ...           ...        ...               ...
# 164                8.2        grande       41.0               4.1
# 165                8.5       pequena       49.0               5.2
# 166                5.3       pequena       42.0               5.1
# 168                9.9        grande       39.0               3.3
# 169                6.8       pequena       56.0               5.1
#
#     area_industria
# 0        industria
# 1       outra_area
# 2        industria
# 3        industria
# 4        industria
# ..             ...
# 164     outra_area
# 165      industria
# 166     outra_area
# 168      industria
# 169     outra_area
#
# [163 rows x 12 columns]

# %% [markdown]
# ## Análises

# %% [markdown]
# ### Exemplo 1.1 - verificar os casos incompletos por linha
#
# Obteremos o número de dados perdidos por linha

# %%
dados_hatco.isna().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 165    0
# 166    2
# 167    1
# 168    2
# 169    0
# Length: 170, dtype: int64

# %%
missings_por_linha = pd.DataFrame({'id': dados_hatco['id'].tolist(),
                                   'n_missings': dados_hatco.isna().sum(axis=1).tolist()})

# %%
missings_por_linha.tail()
# Out:
#       id  n_missings
# 165  266           0
# 166  267           2
# 167  268           1
# 168  269           2
# 169  270           0

# %% [markdown]
# Podemos obter o percentual de dados perdidos por linha.

# %%
dados_hatco.shape[1]
# Out:
# 12

# %%
dados_hatco.columns
# Out:
# Index(['id', 'velocidade_entrega', 'nivel_preco', 'flexibilidade_preco',
#        'imagem_fornecedor', 'qualidade_servico', 'imagem_forca_vendas',
#        'qualidade_produto', 'tamanho_firma', 'nivel_uso', 'nivel_satisfacao',
#        'area_industria'],
#       dtype='object')

# %%
n_colunas = dados_hatco.shape[1] - 1
n_colunas
# Out:
# 11

# %%
missings_por_linha \
    .assign(perc_missings = missings_por_linha['n_missings'] / n_colunas)
# Out:
#       id  n_missings  perc_missings
# 0      1           0       0.000000
# 1      2           0       0.000000
# 2      3           0       0.000000
# 3      4           0       0.000000
# 4      5           0       0.000000
# ..   ...         ...            ...
# 165  266           0       0.000000
# 166  267           2       0.181818
# 167  268           1       0.090909
# 168  269           2       0.181818
# 169  270           0       0.000000
#
# [170 rows x 3 columns]

# %%
missings_por_linha \
    .assign( perc_missings = missings_por_linha['n_missings'] / n_colunas ) \
    .sort_values('perc_missings', ascending = False) \
    .head(20)
# Out:
#       id  n_missings  perc_missings
# 162  263           7       0.636364
# 109  210           7       0.636364
# 113  214           6       0.545455
# 160  261           6       0.545455
# 144  245           5       0.454545
# 132  233           5       0.454545
# 103  204           3       0.272727
# 120  221           3       0.272727
# 123  224           3       0.272727
# 106  207           3       0.272727
# 124  225           2       0.181818
# 101  202           2       0.181818
# 102  203           2       0.181818
# 127  228           2       0.181818
# 147  248           2       0.181818
# 126  227           2       0.181818
# 149  250           2       0.181818
# 131  232           2       0.181818
# 140  241           2       0.181818
# 154  255           2       0.181818

# %%
missings_por_linha = missings_por_linha \
    .assign( perc_missings = missings_por_linha['n_missings'] / n_colunas )

# %%
missings_por_linha.columns
# Out:
# Index(['id', 'n_missings', 'perc_missings'], dtype='object')

# %%
missings_por_linha[missings_por_linha['perc_missings'] > 0.5]['id'].to_list()
# Out:
# [210, 214, 261, 263]

# %%
lista_perdidos = missings_por_linha[missings_por_linha['perc_missings'] > 0.5]['id'].to_list()

# %%
dados_hatco[~dados_hatco['id'].isin(lista_perdidos)]
# Out:
#       id  velocidade_entrega  nivel_preco  flexibilidade_preco  \
# 0      1                 4.1          0.6                  6.9
# 1      2                 1.8          3.0                  6.3
# 2      3                 3.4          5.2                  5.7
# 3      4                 2.7          1.0                  7.1
# 4      5                 6.0          0.9                  9.6
# ..   ...                 ...          ...                  ...
# 165  266                 4.2          2.4                  9.4
# 166  267                 3.8          0.8                  NaN
# 167  268                 3.3          2.6                  9.7
# 168  269                 NaN          1.9                  NaN
# 169  270                 4.5          1.6                  8.7
#
#      imagem_fornecedor  qualidade_servico  imagem_forca_vendas  \
# 0                  4.7                2.4                  2.3
# 1                  6.6                2.5                  4.0
# 2                  6.0                4.3                  2.7
# 3                  5.9                1.8                  2.3
# 4                  7.8                3.4                  4.6
# ..                 ...                ...                  ...
# 165                4.9                3.2                  2.7
# 166                NaN                2.2                  2.6
# 167                3.3                2.9                  1.5
# 168                4.5                1.5                  3.1
# 169                4.6                3.1                  2.1
#
#      qualidade_produto tamanho_firma  nivel_uso  nivel_satisfacao  \
# 0                  5.2       pequena       32.0               4.2
# 1                  8.4        grande       43.0               4.3
# 2                  8.2        grande       48.0               5.2
# 3                  7.8        grande       32.0               3.9
# 4                  4.5       pequena       58.0               6.8
# ..                 ...           ...        ...               ...
# 165                8.5       pequena       49.0               5.2
# 166                5.3       pequena       42.0               5.1
# 167                5.2       pequena       47.0               NaN
# 168                9.9        grande       39.0               3.3
# 169                6.8       pequena       56.0               5.1
#
#     area_industria
# 0        industria
# 1       outra_area
# 2        industria
# 3        industria
# 4        industria
# ..             ...
# 165      industria
# 166     outra_area
# 167      industria
# 168      industria
# 169     outra_area
#
# [166 rows x 12 columns]

# %% [markdown]
# ### Exemplo 1.2 Verificar casos incompletos por coluna

# %% [markdown]
# Obter o número de *missings* por coluna

# %%
dados_hatco.isna().sum()
# Out:
# id                      0
# velocidade_entrega     21
# nivel_preco            13
# flexibilidade_preco    17
# imagem_fornecedor       7
# qualidade_servico       9
# imagem_forca_vendas     6
# qualidade_produto       9
# tamanho_firma           2
# nivel_uso               9
# nivel_satisfacao        7
# area_industria          1
# dtype: int64

# %%
missings_por_coluna = dados_hatco.isna().sum()

# %%
missings_por_coluna = pd.DataFrame( missings_por_coluna,
                                   columns=['n']) \
                                   .reset_index() \
                                   .rename(columns={'index': 'variaveis'})

# %%
missings_por_coluna
# Out:
#               variaveis   n
# 0                    id   0
# 1    velocidade_entrega  21
# 2           nivel_preco  13
# 3   flexibilidade_preco  17
# 4     imagem_fornecedor   7
# 5     qualidade_servico   9
# 6   imagem_forca_vendas   6
# 7     qualidade_produto   9
# 8         tamanho_firma   2
# 9             nivel_uso   9
# 10     nivel_satisfacao   7
# 11       area_industria   1

# %%
n_linhas = dados_hatco.shape[0]

# %%
n_linhas
# Out:
# 170

# %% [markdown]
# Obter o percentual

# %%
n_linhas = dados_hatco.shape[0]

# %%
missings_por_coluna \
    .assign( perc_missings = missings_por_coluna['n'] / n_linhas) \
    .sort_values('n', ascending = False)
# Out:
#               variaveis   n  perc_missings
# 1    velocidade_entrega  21       0.123529
# 3   flexibilidade_preco  17       0.100000
# 2           nivel_preco  13       0.076471
# 5     qualidade_servico   9       0.052941
# 7     qualidade_produto   9       0.052941
# 9             nivel_uso   9       0.052941
# 4     imagem_fornecedor   7       0.041176
# 10     nivel_satisfacao   7       0.041176
# 6   imagem_forca_vendas   6       0.035294
# 8         tamanho_firma   2       0.011765
# 11       area_industria   1       0.005882
# 0                    id   0       0.000000

# %% [markdown]
# ### Identificação dos *missings*

# %% [markdown]
# - Método 1: comparando variáveis qualitativas

# %% [markdown]
# a) Contagem das variáveis qualitativas

# %%
dados_hatco.shape
# Out:
# (170, 12)

# %%
dados_hatco.groupby('tamanho_firma')['id'].count()
# Out:
# tamanho_firma
# grande      65
# pequena    103
# Name: id, dtype: int64

# %%
65+103
# Out:
# 168

# %%
dados_hatco['tamanho_firma'] \
      .value_counts(dropna=False) \
      .to_frame('n') \
      .reset_index() \
      .rename(columns={'index': 'tamanho_firma'})
# Out:
#   tamanho_firma    n
# 0       pequena  103
# 1        grande   65
# 2           NaN    2

# %% [markdown]
# b) Contagem  da tabela cruzada entre variáveis qualitatitivas

# %%
pd.crosstab(dados_hatco.tamanho_firma, dados_hatco.area_industria)
# Out:
# area_industria  industria  outra_area
# tamanho_firma
# grande                 32          32
# pequena                51          52

# %%
pd.crosstab(dados_hatco.tamanho_firma.fillna('NA'),
            dados_hatco.area_industria.fillna('NA'))
# Out:
# area_industria  NA  industria  outra_area
# tamanho_firma
# NA               0          0           2
# grande           1         32          32
# pequena          0         51          52

# %% [markdown]
# ### Tratamento dos *missings*

# %% [markdown]
# - Eliminar todos os *missings*

# %%
dados_hatco.shape
# Out:
# (170, 12)

# %%
dados_hatco \
    .dropna() \
    .shape
# Out:
# (126, 12)

# %% [markdown]
# - Imputar pelo dados mais frequente

# %%
dados_hatco['area_industria'] \
      .value_counts(dropna=False) \
      .to_frame('n') \
      .reset_index() \
      .rename(columns={'index': 'area_industria'})
# Out:
#   area_industria   n
# 0     outra_area  86
# 1      industria  83
# 2            NaN   1

# %%
dados_hatco['area_industria'] \
      .fillna('outra_area') \
      .value_counts(dropna=False) \
      .to_frame('n') \
      .reset_index() \
      .rename(columns={'index': 'area_industria'})
# Out:
#   area_industria   n
# 0     outra_area  87
# 1      industria  83

# %%
dados_hatco['area_industria_2'] = dados_hatco['area_industria'].fillna('outra_area')

# %%
dados_hatco[dados_hatco['area_industria'].isnull()]
# Out:
#       id  velocidade_entrega  nivel_preco  flexibilidade_preco  \
# 113  214                 NaN          2.7                  5.0
#
#      imagem_fornecedor  qualidade_servico  imagem_forca_vendas  \
# 113                NaN                2.2                  NaN
#
#      qualidade_produto tamanho_firma  nivel_uso  nivel_satisfacao  \
# 113                NaN        grande        NaN               3.6
#
#     area_industria area_industria_2
# 113            NaN       outra_area

# %%
dados_hatco
# Out:
#       id  velocidade_entrega  nivel_preco  flexibilidade_preco  \
# 0      1                 4.1          0.6                  6.9
# 1      2                 1.8          3.0                  6.3
# 2      3                 3.4          5.2                  5.7
# 3      4                 2.7          1.0                  7.1
# 4      5                 6.0          0.9                  9.6
# ..   ...                 ...          ...                  ...
# 165  266                 4.2          2.4                  9.4
# 166  267                 3.8          0.8                  NaN
# 167  268                 3.3          2.6                  9.7
# 168  269                 NaN          1.9                  NaN
# 169  270                 4.5          1.6                  8.7
#
#      imagem_fornecedor  qualidade_servico  imagem_forca_vendas  \
# 0                  4.7                2.4                  2.3
# 1                  6.6                2.5                  4.0
# 2                  6.0                4.3                  2.7
# 3                  5.9                1.8                  2.3
# 4                  7.8                3.4                  4.6
# ..                 ...                ...                  ...
# 165                4.9                3.2                  2.7
# 166                NaN                2.2                  2.6
# 167                3.3                2.9                  1.5
# 168                4.5                1.5                  3.1
# 169                4.6                3.1                  2.1
#
#      qualidade_produto tamanho_firma  nivel_uso  nivel_satisfacao  \
# 0                  5.2       pequena       32.0               4.2
# 1                  8.4        grande       43.0               4.3
# 2                  8.2        grande       48.0               5.2
# 3                  7.8        grande       32.0               3.9
# 4                  4.5       pequena       58.0               6.8
# ..                 ...           ...        ...               ...
# 165                8.5       pequena       49.0               5.2
# 166                5.3       pequena       42.0               5.1
# 167                5.2       pequena       47.0               NaN
# 168                9.9        grande       39.0               3.3
# 169                6.8       pequena       56.0               5.1
#
#     area_industria area_industria_2
# 0        industria        industria
# 1       outra_area       outra_area
# 2        industria        industria
# 3        industria        industria
# 4        industria        industria
# ..             ...              ...
# 165      industria        industria
# 166     outra_area       outra_area
# 167      industria        industria
# 168      industria        industria
# 169     outra_area       outra_area
#
# [170 rows x 13 columns]

# %% [markdown]
# - Atribuição média/mediana

# %%
stats = dados_hatco[['flexibilidade_preco', 'imagem_fornecedor']].describe()

# %%
stats
# Out:
#        flexibilidade_preco  imagem_fornecedor
# count           153.000000         163.000000
# mean              7.952288           5.217178
# std               1.391378           1.144099
# min               5.000000           2.500000
# 25%               6.700000           4.500000
# 50%               8.200000           5.000000
# 75%               9.200000           6.000000
# max              10.000000           8.200000

# %%
stats['flexibilidade_preco'].loc['mean']
# Out:
# 7.952287581699348

# %%
stats['flexibilidade_preco'].loc['50%']
# Out:
# 8.2

# %%
dados_hatco[['id', 'flexibilidade_preco', 'imagem_fornecedor']].tail(5)
# Out:
#       id  flexibilidade_preco  imagem_fornecedor
# 165  266                  9.4                4.9
# 166  267                  NaN                NaN
# 167  268                  9.7                3.3
# 168  269                  NaN                4.5
# 169  270                  8.7                4.6

# %%
dados_hatco2 = dados_hatco \
    .assign(flexibilidade_preco2 = dados_hatco['flexibilidade_preco'].fillna(stats['flexibilidade_preco'].loc['50%']) ) \
    .assign(imagem_fornecedor2 = dados_hatco['imagem_fornecedor'].fillna(stats['imagem_fornecedor'].loc['mean']) )

# %%
dados_hatco2[['id', 'flexibilidade_preco', 'flexibilidade_preco2', 'imagem_fornecedor', 'imagem_fornecedor2']].tail(5)
# Out:
#       id  flexibilidade_preco  flexibilidade_preco2  imagem_fornecedor  \
# 165  266                  9.4                   9.4                4.9
# 166  267                  NaN                   8.2                NaN
# 167  268                  9.7                   9.7                3.3
# 168  269                  NaN                   8.2                4.5
# 169  270                  8.7                   8.7                4.6
#
#      imagem_fornecedor2
# 165            4.900000
# 166            5.217178
# 167            3.300000
# 168            4.500000
# 169            4.600000

# %%
dados_hatco2[['flexibilidade_preco', 'flexibilidade_preco2', 'imagem_fornecedor', 'imagem_fornecedor2']].describe()
# Out:
#        flexibilidade_preco  flexibilidade_preco2  imagem_fornecedor  \
# count           153.000000            170.000000         163.000000
# mean              7.952288              7.977059           5.217178
# std               1.391378              1.321646           1.144099
# min               5.000000              5.000000           2.500000
# 25%               6.700000              6.900000           4.500000
# 50%               8.200000              8.200000           5.000000
# 75%               9.200000              9.100000           6.000000
# max              10.000000             10.000000           8.200000
#
#        imagem_fornecedor2
# count          170.000000
# mean             5.217178
# std              1.120154
# min              2.500000
# 25%              4.600000
# 50%              5.100000
# 75%              5.900000
# max              8.200000
