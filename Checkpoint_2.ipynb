# %% [markdown]
# <a href="https://colab.research.google.com/github/Lorenzopiloto/Statistics-DS/blob/main/Checkpoint_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Checkpoint 2

# %% [markdown]
# ## carregar Módulos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # carregar dados

# %%
path = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
path_dead =  'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'

# %%
dados_paises_covid = pd.read_csv(path)
dados_paises_covid_dead = pd.read_csv(path_dead)

# %%
dados_paises_covid
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  \
# 0          0        0        0        0        0  ...   209322  209340
# 1          0        0        0        0        0  ...   334391  334408
# 2          0        0        0        0        0  ...   271441  271448
# 3          0        0        0        0        0  ...    47866   47875
# 4          0        0        0        0        0  ...   105255  105277
# ..       ...      ...      ...      ...      ...  ...      ...     ...
# 284        0        0        0        0        0  ...   703228  703228
# 285        0        0        0        0        0  ...      535     535
# 286        0        0        0        0        0  ...    11945   11945
# 287        0        0        0        0        0  ...   343012  343012
# 288        0        0        0        0        0  ...   263921  264127
#
#      3/2/23  3/3/23  3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0    209358  209362  209369  209390  209406  209436  209451  209451
# 1    334408  334427  334427  334427  334427  334427  334443  334457
# 2    271463  271469  271469  271477  271477  271490  271494  271496
# 3     47875   47875   47875   47875   47875   47875   47890   47890
# 4    105277  105277  105277  105277  105277  105277  105288  105288
# ..      ...     ...     ...     ...     ...     ...     ...     ...
# 284  703228  703228  703228  703228  703228  703228  703228  703228
# 285     535     535     535     535     535     535     535     535
# 286   11945   11945   11945   11945   11945   11945   11945   11945
# 287  343079  343079  343079  343135  343135  343135  343135  343135
# 288  264127  264127  264127  264127  264127  264127  264276  264276
#
# [289 rows x 1147 columns]

# %% [markdown]
# # Ajustes

# %% [markdown]
# - Nomes das colunas

# %%
dados_paises_covid.rename(columns={"Province/State": "province",
                                   "Country/Region": "country"},
                          inplace=True)

# %%
dados_paises_covid_dead.rename(columns={"Province/State": "province",
                                        "Country/Region": "country"},
                               inplace=True)

# %%
dados_paises_covid_dead.columns
# Out:
# Index(['province', 'country', 'Lat', 'Long', '1/22/20', '1/23/20', '1/24/20',
#        '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '2/28/23', '3/1/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23',
#        '3/7/23', '3/8/23', '3/9/23'],
#       dtype='object', length=1147)

# %%
dados_paises_covid_dead
# Out:
#     province               country        Lat        Long  1/22/20  1/23/20  \
# 0        NaN           Afghanistan  33.939110   67.709953        0        0
# 1        NaN               Albania  41.153300   20.168300        0        0
# 2        NaN               Algeria  28.033900    1.659600        0        0
# 3        NaN               Andorra  42.506300    1.521800        0        0
# 4        NaN                Angola -11.202700   17.873900        0        0
# ..       ...                   ...        ...         ...      ...      ...
# 284      NaN    West Bank and Gaza  31.952200   35.233200        0        0
# 285      NaN  Winter Olympics 2022  39.904200  116.407400        0        0
# 286      NaN                 Yemen  15.552727   48.516388        0        0
# 287      NaN                Zambia -13.133897   27.849332        0        0
# 288      NaN              Zimbabwe -19.015438   29.154857        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  \
# 0          0        0        0        0  ...     7896    7896    7896    7896
# 1          0        0        0        0  ...     3598    3598    3598    3598
# 2          0        0        0        0  ...     6881    6881    6881    6881
# 3          0        0        0        0  ...      165     165     165     165
# 4          0        0        0        0  ...     1933    1933    1933    1933
# ..       ...      ...      ...      ...  ...      ...     ...     ...     ...
# 284        0        0        0        0  ...     5708    5708    5708    5708
# 285        0        0        0        0  ...        0       0       0       0
# 286        0        0        0        0  ...     2159    2159    2159    2159
# 287        0        0        0        0  ...     4057    4057    4057    4057
# 288        0        0        0        0  ...     5663    5668    5668    5668
#
#      3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0      7896    7896    7896    7896    7896    7896
# 1      3598    3598    3598    3598    3598    3598
# 2      6881    6881    6881    6881    6881    6881
# 3       165     165     165     165     165     165
# 4      1933    1933    1933    1933    1933    1933
# ..      ...     ...     ...     ...     ...     ...
# 284    5708    5708    5708    5708    5708    5708
# 285       0       0       0       0       0       0
# 286    2159    2159    2159    2159    2159    2159
# 287    4057    4057    4057    4057    4057    4057
# 288    5668    5668    5668    5668    5671    5671
#
# [289 rows x 1147 columns]

# %% [markdown]
# - Reajustar dados

# %%
dados_paises_covid = dados_paises_covid.melt(id_vars=['province', 'country', 'Lat', 'Long'],
                                             var_name = 'date',
                                             value_name = 'infected')

# %%
dados_paises_covid_dead = dados_paises_covid_dead.melt(id_vars=['province', 'country', 'Lat', 'Long'],
                                                       var_name = 'date',
                                                       value_name = 'dead')

# %%
dados_paises_covid_dead.tail()
# Out:
#        province               country        Lat        Long    date  dead
# 330322      NaN    West Bank and Gaza  31.952200   35.233200  3/9/23  5708
# 330323      NaN  Winter Olympics 2022  39.904200  116.407400  3/9/23     0
# 330324      NaN                 Yemen  15.552727   48.516388  3/9/23  2159
# 330325      NaN                Zambia -13.133897   27.849332  3/9/23  4057
# 330326      NaN              Zimbabwe -19.015438   29.154857  3/9/23  5671

# %%
dados_paises_covid_dead.shape
# Out:
# (330327, 6)

# %%
dados_paises_covid_dead.dtypes
# Out:
# province     object
# country      object
# Lat         float64
# Long        float64
# date         object
# dead          int64
# dtype: object

# %% [markdown]
# - Ajustar datas

# %%
dados_paises_covid['date'] = pd.to_datetime(dados_paises_covid['date'],
                                            infer_datetime_format='True')
# Out:
# <ipython-input-14-c40cd7852016>:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   dados_paises_covid['date'] = pd.to_datetime(dados_paises_covid['date'],
# <ipython-input-14-c40cd7852016>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dados_paises_covid['date'] = pd.to_datetime(dados_paises_covid['date'],

# %%
dados_paises_covid_dead['date'] = pd.to_datetime(dados_paises_covid_dead['date'],
                                                 infer_datetime_format='True')
# Out:
# <ipython-input-15-233e13507b25>:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   dados_paises_covid_dead['date'] = pd.to_datetime(dados_paises_covid_dead['date'],
# <ipython-input-15-233e13507b25>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dados_paises_covid_dead['date'] = pd.to_datetime(dados_paises_covid_dead['date'],

# %%
dados_paises_covid.tail()
# Out:
#        province               country        Lat        Long       date  \
# 330322      NaN    West Bank and Gaza  31.952200   35.233200 2023-03-09
# 330323      NaN  Winter Olympics 2022  39.904200  116.407400 2023-03-09
# 330324      NaN                 Yemen  15.552727   48.516388 2023-03-09
# 330325      NaN                Zambia -13.133897   27.849332 2023-03-09
# 330326      NaN              Zimbabwe -19.015438   29.154857 2023-03-09
#
#         infected
# 330322    703228
# 330323       535
# 330324     11945
# 330325    343135
# 330326    264276

# %%
dados_paises_covid_dead.tail()
# Out:
#        province               country        Lat        Long       date  dead
# 330322      NaN    West Bank and Gaza  31.952200   35.233200 2023-03-09  5708
# 330323      NaN  Winter Olympics 2022  39.904200  116.407400 2023-03-09     0
# 330324      NaN                 Yemen  15.552727   48.516388 2023-03-09  2159
# 330325      NaN                Zambia -13.133897   27.849332 2023-03-09  4057
# 330326      NaN              Zimbabwe -19.015438   29.154857 2023-03-09  5671

# %%
dados_paises_covid_dead.dtypes
# Out:
# province            object
# country             object
# Lat                float64
# Long               float64
# date        datetime64[ns]
# dead                 int64
# dtype: object

# %% [markdown]
# - Combinar os datasets

# %%
dados_paises_covid.shape
# Out:
# (330327, 6)

# %%
dados_paises_covid_dead.shape
# Out:
# (330327, 6)

# %%
dados_covid = pd.merge(dados_paises_covid, dados_paises_covid_dead,
                       on = ['province', 'country',	'Lat',	'Long',	'date'],
                       how = 'inner')

# %%
dados_covid.tail()
# Out:
#        province               country        Lat        Long       date  \
# 330322      NaN    West Bank and Gaza  31.952200   35.233200 2023-03-09
# 330323      NaN  Winter Olympics 2022  39.904200  116.407400 2023-03-09
# 330324      NaN                 Yemen  15.552727   48.516388 2023-03-09
# 330325      NaN                Zambia -13.133897   27.849332 2023-03-09
# 330326      NaN              Zimbabwe -19.015438   29.154857 2023-03-09
#
#         infected  dead
# 330322    703228  5708
# 330323       535     0
# 330324     11945  2159
# 330325    343135  4057
# 330326    264276  5671

# %%
dados_covid.shape
# Out:
# (330327, 7)

# %% [markdown]
# # Questão 1

# %%
data_max = np.max(dados_covid['date'])

# %%
data_max
# Out:
# Timestamp('2023-03-09 00:00:00')

# %%
dados_atual = dados_covid[dados_covid['date'] == data_max].reset_index(drop=True)

# %%
dados_atual
# Out:
#     province               country        Lat        Long       date  \
# 0        NaN           Afghanistan  33.939110   67.709953 2023-03-09
# 1        NaN               Albania  41.153300   20.168300 2023-03-09
# 2        NaN               Algeria  28.033900    1.659600 2023-03-09
# 3        NaN               Andorra  42.506300    1.521800 2023-03-09
# 4        NaN                Angola -11.202700   17.873900 2023-03-09
# ..       ...                   ...        ...         ...        ...
# 284      NaN    West Bank and Gaza  31.952200   35.233200 2023-03-09
# 285      NaN  Winter Olympics 2022  39.904200  116.407400 2023-03-09
# 286      NaN                 Yemen  15.552727   48.516388 2023-03-09
# 287      NaN                Zambia -13.133897   27.849332 2023-03-09
# 288      NaN              Zimbabwe -19.015438   29.154857 2023-03-09
#
#      infected  dead
# 0      209451  7896
# 1      334457  3598
# 2      271496  6881
# 3       47890   165
# 4      105288  1933
# ..        ...   ...
# 284    703228  5708
# 285       535     0
# 286     11945  2159
# 287    343135  4057
# 288    264276  5671
#
# [289 rows x 7 columns]

# %%
filtro_paises = ['Brazil', 'US', 'Italy', 'Canada']
dados_atual_paises = dados_atual[dados_atual['country'].isin(filtro_paises)].reset_index(drop=True)

# %%
dados_atual_paises
# Out:
#                      province country       Lat       Long       date  \
# 0                         NaN  Brazil -14.23500  -51.92530 2023-03-09
# 1                     Alberta  Canada  53.93330 -116.57650 2023-03-09
# 2            British Columbia  Canada  53.72670 -127.64760 2023-03-09
# 3            Diamond Princess  Canada   0.00000    0.00000 2023-03-09
# 4              Grand Princess  Canada   0.00000    0.00000 2023-03-09
# 5                    Manitoba  Canada  53.76090  -98.81390 2023-03-09
# 6               New Brunswick  Canada  46.56530  -66.46190 2023-03-09
# 7   Newfoundland and Labrador  Canada  53.13550  -57.66040 2023-03-09
# 8       Northwest Territories  Canada  64.82550 -124.84570 2023-03-09
# 9                 Nova Scotia  Canada  44.68200  -63.74430 2023-03-09
# 10                    Nunavut  Canada  70.29980  -83.10760 2023-03-09
# 11                    Ontario  Canada  51.25380  -85.32320 2023-03-09
# 12       Prince Edward Island  Canada  46.51070  -63.41680 2023-03-09
# 13                     Quebec  Canada  52.93990  -73.54910 2023-03-09
# 14     Repatriated Travellers  Canada       NaN        NaN 2023-03-09
# 15               Saskatchewan  Canada  52.93990 -106.45090 2023-03-09
# 16                      Yukon  Canada  64.28230 -135.00000 2023-03-09
# 17                        NaN   Italy  41.87194   12.56738 2023-03-09
# 18                        NaN      US  40.00000 -100.00000 2023-03-09
#
#      infected     dead
# 0    37076053   699276
# 1      629269     5622
# 2      396817     5249
# 3           0        1
# 4          13        0
# 5      154712     2464
# 6       88866      834
# 7       54757      318
# 8       11511       22
# 9      140793      794
# 10       3531        7
# 11    1601325    16234
# 12      56523       93
# 13    1320325    18160
# 14         13        0
# 15     153651     1890
# 16       4989       32
# 17   25603510   188322
# 18  103802702  1123836

# %%
dados_atual_paises = dados_atual_paises.groupby(['date', 'country']) \
                                       .agg(infected = pd.NamedAgg('infected', 'sum'),
                                             dead = pd.NamedAgg('dead', 'sum')) \
                                       .reset_index()

# %%
dados_atual_paises
# Out:
#         date country   infected     dead
# 0 2023-03-09  Brazil   37076053   699276
# 1 2023-03-09  Canada    4617095    51720
# 2 2023-03-09   Italy   25603510   188322
# 3 2023-03-09      US  103802702  1123836

# %% [markdown]
# # Questão 2

# %%
country_dict = {'Brazil': 212559417, 'US': 331002651, 'Italy': 60461826, 'Canada': 37742154}

# %%
pop_df = pd.DataFrame(list(country_dict.items()), columns=['country', 'population'])

# %%
pop_df
# Out:
#   country  population
# 0  Brazil   212559417
# 1      US   331002651
# 2   Italy    60461826
# 3  Canada    37742154

# %%
dados_atual_paises = dados_atual_paises.merge(pop_df, on = 'country', how = 'inner')

# %%
dados_atual_paises
# Out:
#         date country   infected     dead  population
# 0 2023-03-09  Brazil   37076053   699276   212559417
# 1 2023-03-09  Canada    4617095    51720    37742154
# 2 2023-03-09   Italy   25603510   188322    60461826
# 3 2023-03-09      US  103802702  1123836   331002651

# %% [markdown]
# # Questão 3

# %%
def prob_com_e(infectados_no_pais, populacao_total):
  return infectados_no_pais/populacao_total

# %%
def prob_dado_que(infectados_no_pais, populacao_do_pais, populacao_total):
  return (infectados_no_pais/populacao_total)/(populacao_do_pais/populacao_total)

# %% [markdown]
# - a) infecatdo covid:

# %%
total_infectados = np.sum(dados_atual_paises['infected'])

# %%
total = np.sum(dados_atual_paises['population'])

# %%
total_infectados / total
# Out:
# 0.2666070611451231

# %% [markdown]
# b) infecatdo covid e ser Brasileiro

# %%
dados_atual_paises[dados_atual_paises['country'] == 'Brazil']['infected'].tolist()[0]
# Out:
# 37076053

# %%
dados_atual_paises[dados_atual_paises['country'] == 'Brazil']['infected'].tolist()[0]
# Out:
# 37076053

# %%
infectado_e_brasil = dados_atual_paises[dados_atual_paises['country'] == 'Brazil']['infected'].tolist()[0]

# %%
f"O número de infectados no Brasil é de {infectado_e_brasil:,.2f}"
# Out:
# 'O número de infectados no Brasil é de 37,076,053.00'

# %%
infectado_e_brasil / total
# Out:
# 0.05777191410412537

# %%
prob_com_e(infectados_no_pais = infectado_e_brasil,
           populacao_total = total)
# Out:
# 0.05777191410412537

# %% [markdown]
#  c) infectado covid | ser Brasileiro

# %%
total_brasil = dados_atual_paises[dados_atual_paises['country'] == 'Brazil']['population'].tolist()[0]

# %%
(infectado_e_brasil / total) / (total_brasil / total)
# Out:
# 0.17442677216225147

# %%
infectado_e_brasil / total_brasil
# Out:
# 0.17442677216225147

# %%
prob_dado_que(infectados_no_pais = infectado_e_brasil,
              populacao_do_pais = total_brasil,
              populacao_total = total)
# Out:
# 0.17442677216225147

# %% [markdown]
# d) Compare estes resultados com o mesmo período do ano passado

# %%
data_max - relativedelta(days=3)
# Out:
# Timestamp('2023-03-06 00:00:00')

# %%
ano_antes = data_max - relativedelta(years=1)

# %%
dados_covid[dados_covid['date'] == ano_antes].reset_index(drop=False)
# Out:
#       index province               country        Lat        Long       date  \
# 0    224553      NaN           Afghanistan  33.939110   67.709953 2022-03-09
# 1    224554      NaN               Albania  41.153300   20.168300 2022-03-09
# 2    224555      NaN               Algeria  28.033900    1.659600 2022-03-09
# 3    224556      NaN               Andorra  42.506300    1.521800 2022-03-09
# 4    224557      NaN                Angola -11.202700   17.873900 2022-03-09
# ..      ...      ...                   ...        ...         ...        ...
# 284  224837      NaN    West Bank and Gaza  31.952200   35.233200 2022-03-09
# 285  224838      NaN  Winter Olympics 2022  39.904200  116.407400 2022-03-09
# 286  224839      NaN                 Yemen  15.552727   48.516388 2022-03-09
# 287  224840      NaN                Zambia -13.133897   27.849332 2022-03-09
# 288  224841      NaN              Zimbabwe -19.015438   29.154857 2022-03-09
#
#      infected  dead
# 0      175525  7636
# 1      272412  3483
# 2      265346  6860
# 3       38794   152
# 4       98855  1900
# ..        ...   ...
# 284    652763  5588
# 285       533     0
# 286     11781  2138
# 287    314641  3960
# 288    240343  5400
#
# [289 rows x 8 columns]

# %%
dados_ano_antes = dados_covid[dados_covid['date'] == ano_antes].reset_index(drop=True)

# %%
dados_ano_antes_paises = dados_ano_antes[dados_ano_antes['country'].isin(filtro_paises)].reset_index(drop=True)

# %%
dados_ano_antes_paises = dados_ano_antes_paises.groupby(['date', 'country']) \
                                               .agg(infected = pd.NamedAgg('infected', 'sum'),
                                                    dead = pd.NamedAgg('dead', 'sum')) \
                                               .reset_index()

# %%
dados_ano_antes_paises = dados_ano_antes_paises.merge(pop_df, on = 'country', how = 'inner')

# %%
dados_ano_antes_paises
# Out:
#         date country  infected    dead  population
# 0 2022-03-09  Brazil  29198101  653767   212559417
# 1 2022-03-09  Canada   3356440   37158    37742154
# 2 2022-03-09   Italy  13159342  156357    60461826
# 3 2022-03-09      US  79536060  963275   331002651

# %% [markdown]
# - infectados

# %%
total_infectados = np.sum(dados_ano_antes_paises['infected'])

# %%
total = np.sum(dados_ano_antes_paises['population'])

# %%
total_infectados / total
# Out:
# 0.19516448928753552

# %% [markdown]
# - prob e

# %%
infectado_e_brasil = dados_ano_antes_paises[dados_ano_antes_paises['country'] == 'Brazil']['infected'].tolist()[0]

# %%
prob_com_e(infectados_no_pais = infectado_e_brasil,
           populacao_total = total)
# Out:
# 0.045496487529985384

# %% [markdown]
# - prob |

# %%
total_brasil = dados_ano_antes_paises[dados_ano_antes_paises['country'] == 'Brazil']['population'].tolist()[0]

# %%
prob_dado_que(infectados_no_pais = infectado_e_brasil,
              populacao_do_pais = total_brasil,
              populacao_total = total)
# Out:
# 0.13736441985066228

# %% [markdown]
# e) infectado covid e ser USA

# %%
infectado_e_usa = dados_atual_paises[dados_atual_paises['country'] == 'US']['infected'].tolist()[0]

# %%
infectado_e_usa / total
# Out:
# 0.16174539354877185

# %% [markdown]
# f) infectado covid | ser USA

# %%
total_usa = dados_atual_paises[dados_atual_paises['country'] == 'US']['population'].tolist()[0]

# %%
(infectado_e_usa / total) / (total_usa / total)
# Out:
# 0.3136008176562912

# %%
infectado_e_usa / total_usa
# Out:
# 0.3136008176562912

# %% [markdown]
# g) infectado covid e ser italiano

# %%
infectado_e_italia = dados_atual_paises[dados_atual_paises['country'] == 'Italy']['infected'].tolist()[0]

# %%
infectado_e_italia / total
# Out:
# 0.039895395027192214

# %% [markdown]
# h) infectado covid | ser italiano

# %%
total_italia = dados_atual_paises[dados_atual_paises['country'] == 'Italy']['population'].tolist()[0]

# %%
(infectado_e_italia / total) / (total_italia / total)
# Out:
# 0.4234657087597718

# %%
infectado_e_italia / total_italia
# Out:
# 0.42346570875977185

# %% [markdown]
# # Questão 4

# %% [markdown]
# - Morte covid

# %%
total_mortos = np.sum(dados_atual_paises['dead'])

# %%
total = np.sum(dados_atual_paises['population'])

# %%
total_mortos / total
# Out:
# 0.0032148070257527863

# %% [markdown]
# b) Morte e ser brasileiro

# %%
morto_e_brasil = dados_atual_paises[dados_atual_paises['country'] == 'Brazil']['dead'].tolist()[0]

# %%
morto_e_brasil / total
# Out:
# 0.0010896120201111044

# %% [markdown]
# c) morte covid | ser Brasileiro

# %%
total_brasil = dados_atual_paises[dados_atual_paises['country'] == 'Brazil']['population'].tolist()[0]

# %%
(morto_e_brasil / total) / (total_brasil / total)
# Out:
# 0.003289790731783951

# %%
morto_e_brasil / total_brasil
# Out:
# 0.003289790731783951

# %% [markdown]
# d) Morte covid e ser USA

# %%
morte_e_usa = dados_atual_paises[dados_atual_paises['country'] == 'US']['dead'].tolist()[0]

# %%
morte_e_usa / total
# Out:
# 0.0017511615073784645

# %% [markdown]
# e) Morte covid | ser USA

# %%
total_usa = dados_atual_paises[dados_atual_paises['country'] == 'US']['population'].tolist()[0]

# %%
(morte_e_usa / total) / (total_usa / total)
# Out:
# 0.003395247731716807

# %%
morte_e_usa / total_usa
# Out:
# 0.0033952477317168075

# %% [markdown]
# f) Morte covid e ser italiano

# %%
morte_e_italia = dados_atual_paises[dados_atual_paises['country'] == 'Italy']['dead'].tolist()[0]

# %%
morte_e_italia / total
# Out:
# 0.0002934433826577251

# %% [markdown]
# g) Morte covid | ser italiano

# %%
total_italia = dados_atual_paises[dados_atual_paises['country'] == 'Italy']['population'].tolist()[0]

# %%
(morte_e_italia / total) / (total_italia / total)
# Out:
# 0.0031147256452360534

# %%
morte_e_italia / total_italia
# Out:
# 0.0031147256452360534
