# %% [markdown]
# <a href="https://colab.research.google.com/github/Lorenzopiloto/Statistics-DS/blob/main/Exemplos_Testes_t.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exemplos Testes t

# %% [markdown]
# ## Carregar Módulos

# %%
! sudo pip install scipy==1.11.0
# Out:
# Collecting scipy==1.11.0
#   Downloading scipy-1.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy==1.11.0) (1.26.4)
# WARNING: The candidate selected for download or install is a yanked version: 'scipy' candidate (version 1.11.0 at https://files.pythonhosted.org/packages/5a/55/ec296aa9399d00f5d6794b90d96b5cce5eeb46c62450173fedb2b3b7ef72/scipy-1.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/scipy/) (requires-python:<3.13,>=3.9))
# Reason for being yanked: License Violation
# Downloading scipy-1.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 6.8 MB/s eta 0:00:00
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# Successfully installed scipy-1.11.0

# %%
import numpy as np
import pandas as pd
from scipy import stats as st

# %% [markdown]
# ## Carregar Dados

# %%
dados_profs = pd.read_csv('salarios_profs.csv',
                          sep = ';',
                          decimal = ',',
                          encoding = 'latin1')

# %%
dados_profs.shape
# Out:
# (22584, 13)

# %%
dados_profs.head()
# Out:
#                             NOME UNID_ORGAO  \
# 0               Abel Elias Rahal    PUSP-RP
# 1                 Abel Lavorenti      ESALQ
# 2      Abelardo Cecilio de Souza       FMVZ
# 3                Abib Salim Cury       FORP
# 4  Abidias Lourenco de Alcantara        FCF
#
#                             DEPTO_SETOR   JORNADA  CATEGORIA        CLASSE  \
# 0  Seção Técnica de Práticas Esportivas  30 Horas  Celetista    Superior 2
# 1                               Inativo     RDIDP   Doc Apos  Prof Titular
# 2                        Clínica Médica  40 Horas  Celetista      Básico 3
# 3                               Inativo       RTP   Doc Apos  Prof Titular
# 4         Seção de Manutenção e Reparos  40 Horas  Celetista      Básico 2
#
#   REF_MS                            FUNCAO FUNCAO_ESTRUTURA  TEMPO_USP  \
# 0      A  Educador Em Praticas Desportivas              NaN       46.0
# 1   MS-6                 Professor Titular              NaN        0.0
# 2      A           Auxiliar de Laboratorio              NaN       29.0
# 3   MS-6                 Professor Titular              NaN        0.0
# 4      A                         Encanador              NaN       22.0
#
#    PARCELAS_EVENTUAIS  SALARIO_MENSAL  SALARIO_MENSAL_LIQUIDO
# 0            18432.97        12967.38                17584.07
# 1            27516.80        27516.80                38598.04
# 2             6710.24         6710.24                 7317.24
# 3             7910.41         7910.41                10064.15
# 4             4567.32         4636.18                 5389.03

# %% [markdown]
# ## Teste t 1 grupo

# %%
dados_profs_filtrados = dados_profs[(dados_profs['FUNCAO'] == 'Professor Titular') & \
                                    (dados_profs['JORNADA'] == 'RDIDP') & \
                                    (dados_profs['UNID_ORGAO'] == 'ICMC')]

# %%
dados_profs_filtrados = dados_profs_filtrados[['UNID_ORGAO', 'SALARIO_MENSAL_LIQUIDO']].reset_index(drop=True)

# %%
dados_profs_filtrados.groupby('UNID_ORGAO') \
                     .agg(media_salarial = pd.NamedAgg('SALARIO_MENSAL_LIQUIDO', 'mean'),
                          dp_salarial = pd.NamedAgg('SALARIO_MENSAL_LIQUIDO', 'std'),
                          n = pd.NamedAgg('SALARIO_MENSAL_LIQUIDO', 'count')) \
                     .reset_index()
# Out:
#   UNID_ORGAO  media_salarial  dp_salarial   n
# 0       ICMC    23949.381515  7989.302164  33

# %%
st.ttest_1samp(a=dados_profs_filtrados['SALARIO_MENSAL_LIQUIDO'],
               popmean=20000,
               alternative = 'greater')
# Out:
# TtestResult(statistic=2.839731063414258, pvalue=0.003892164914708257, df=32)

# %% [markdown]
# ## Teste t dois grupos

# %%
dados_profs_filtrados = dados_profs[(dados_profs['FUNCAO'] == 'Professor Titular') & \
                                    (dados_profs['JORNADA'] == 'RDIDP') & \
                                    (dados_profs['UNID_ORGAO'].isin(['FEA', 'ICMC']))]

# %%
dados_profs_filtrados = dados_profs_filtrados[['UNID_ORGAO', 'SALARIO_MENSAL_LIQUIDO']].reset_index(drop=True)

# %%
dados_profs_filtrados.groupby('UNID_ORGAO') \
                     .agg(media_salarial = pd.NamedAgg('SALARIO_MENSAL_LIQUIDO', 'mean'),
                          dp_salarial = pd.NamedAgg('SALARIO_MENSAL_LIQUIDO', 'std'),
                          n = pd.NamedAgg('SALARIO_MENSAL_LIQUIDO', 'count')) \
                     .reset_index()
# Out:
#   UNID_ORGAO  media_salarial  dp_salarial   n
# 0        FEA    23603.542647  6314.436911  68
# 1       ICMC    23949.381515  7989.302164  33
